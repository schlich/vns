# %%
# %matplotlib inline

# %%
import xarray as xr
from dask.distributed import Client

# %%
client = Client(n_workers=2, threads_per_worker=2, memory_limit="1GB")
client
# Out:
# <Client: 'tcp://127.0.0.1:42391' processes=2 threads=4, memory=1.86 GiB>
